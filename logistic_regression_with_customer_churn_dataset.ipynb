# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.select_dtypes(include='object').columns:
  df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
for i in df.columns:
  plt.boxplot(df[i])
  print(i)
  plt.ylabel("count")
  plt.show()
# Out:
# customerID
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# Churn

# %%
out_list=["SeniorCitizen","PhoneService"]
for i in out_list:
  q1=df[i].quantile(0.25)
  q3=df[i].quantile(0.75)
  iqr=q3-q1
  upper_bound=q3+(1.5*iqr)
  lower_bound=q1-(1.5*iqr)
  df=df[(df[i]>=lower_bound) & (df[i]<=upper_bound)]

# %%
for i in df.columns:
  plt.boxplot(df[i])
  print(i)
  plt.ylabel("count")
  plt.show()
# Out:
# customerID
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# Churn

# %%
df=df.drop_duplicates()
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 4           6511       0              0        0           0       2
# 5           6551       0              0        0           0       8
# 6           1002       1              0        0           1      22
# ...          ...     ...            ...      ...         ...     ...
# 7035        5995       1              0        0           0      19
# 7037        1758       0              0        0           0      72
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 4           6511       0              0        0           0       2
# 5           6551       0              0        0           0       8
# 6           1002       1              0        0           1      22
# ...          ...     ...            ...      ...         ...     ...
# 7035        5995       1              0        0           0      19
# 7037        1758       0              0        0           0      72
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 1                1              0                0               2
# ...

# %%
y
# Out:
# 1       0
# 2       1
# 4       1
# 5       1
# 6       0
#        ..
# 7035    0
# 7037    0
# 7038    0
# 7039    0
# 7042    0
# Name: Churn, Length: 5323, dtype: int64

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
rfe=RFE(model)

# %%
rfe.fit(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
rfe.support_
# Out:
# array([False,  True, False, False,  True,  True,  True,  True, False,
#         True,  True, False,  True, False, False,  True,  True, False,
#        False, False])

# %%
select_indices=[i for i,data in enumerate(rfe.support_) if data==True]
select_indices
# Out:
# [1, 4, 5, 6, 7, 9, 10, 12, 15, 16]

# %%
column_names=x.columns

# %%
selected_column_names=[column_names[i] for i in select_indices]

# %%
selected_column_names
# Out:
# ['gender',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'TechSupport',
#  'Contract',
#  'PaperlessBilling']

# %%
x=x.loc[:,['gender',
 'Dependents',
 'tenure',
 'PhoneService',
 'MultipleLines',
 'OnlineSecurity',
 'OnlineBackup',
 'TechSupport',
 'Contract',
 'PaperlessBilling']]

# %%
x
# Out:
#       gender  Dependents  tenure  PhoneService  MultipleLines  OnlineSecurity  \
# 1          1           0      34             1              0               2
# 2          1           0       2             1              0               2
# 4          0           0       2             1              0               0
# 5          0           0       8             1              2               0
# 6          1           1      22             1              2               0
# ...      ...         ...     ...           ...            ...             ...
# 7035       1           0      19             1              0               0
# 7037       0           0      72             1              0               1
# 7038       1           1      24             1              2               2
# 7039       0           1      72             1              2               0
# 7042       1           0      66             1              0               2
#
# ...

# %%
y
# Out:
# 1       0
# 2       1
# 4       1
# 5       1
# 6       0
#        ..
# 7035    0
# 7037    0
# 7038    0
# 7039    0
# 7042    0
# Name: Churn, Length: 5323, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80,random_state=0)

# %%
x_train
# Out:
#       gender  Dependents  tenure  PhoneService  MultipleLines  OnlineSecurity  \
# 2595       0           0      71             1              2               0
# 2408       0           1      45             1              0               1
# 6329       0           0      46             1              0               0
# 5102       0           0      72             1              2               2
# 961        1           0      17             1              0               1
# ...      ...         ...     ...           ...            ...             ...
# 6510       0           1      46             1              2               2
# 4280       1           1      64             1              0               1
# 2146       0           0      62             1              2               2
# 3410       1           0       3             1              0               0
# 3568       0           0      21             1              0               0
#
# ...

# %%
y_train
# Out:
# 2595    0
# 2408    0
# 6329    0
# 5102    0
# 961     0
#        ..
# 6510    0
# 4280    0
# 2146    0
# 3410    1
# 3568    0
# Name: Churn, Length: 4258, dtype: int64

# %%
x_train.shape
# Out:
# (4258, 10)

# %%
y_train.shape
# Out:
# (4258,)

# %%
x_test
# Out:
#       gender  Dependents  tenure  PhoneService  MultipleLines  OnlineSecurity  \
# 1130       1           1      26             1              0               1
# 51         0           0      15             1              0               2
# 891        1           1      50             1              2               0
# 6528       1           1      70             1              0               1
# 5857       0           1      17             1              2               0
# ...      ...         ...     ...           ...            ...             ...
# 6737       0           0      63             1              2               0
# 2963       0           1      34             1              2               1
# 4399       0           0      66             1              2               2
# 6370       0           0      45             1              2               0
# 5834       0           0      65             1              2               2
#
# ...

# %%
y_test
# Out:
# 1130    0
# 51      1
# 891     1
# 6528    0
# 5857    1
#        ..
# 6737    0
# 2963    0
# 4399    0
# 6370    1
# 5834    0
# Name: Churn, Length: 1065, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7953051643192488

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[735,  80],
#        [138, 112]])

# %%
lr.predict([[1130	,1	,1	,26	,1	,0	,1	,1	,1	,2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
